# %% [markdown]
# # Test 2: HistWords SGNS Alignment
#
# This notebook focuses only on the HistWords / Stanford SGNS embeddings. It loads decade-bucketed SGNS matrices and vocab, aligns all decades to a reference decade using orthogonal Procrustes, and then constructs a spectered (time-mixed) SGNS representation. The core goal is to separate “method behavior” from “small corpus noise” by validating the SGNS pipeline end-to-end and directly comparing baseline SGNS neighbors to spectered SGNS neighbors.

# %%
# If you run this in a fresh environment, uncomment:
# !pip install numpy pandas matplotlib scipy

from pathlib import Path
from typing import Dict, List, Tuple, Optional
import re, glob, pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.linalg import orthogonal_procrustes

pd.set_option("display.max_colwidth", 180)

# %% [markdown]
# ## 0) Config
#
# Set the path to your HistWords SGNS decade buckets.

# %%
# Your path (Windows)
SGNS_DIR = Path(r"G:\My Drive\ThesisMaterial\Computation\data\sgns")

# Neighbor inspection
K_NEIGHBORS = 150
KEEP_K = 12

# Alignment config
N_ANCHORS = 5000
ANCHOR_SEED = 7

# Anchor presence requirement (fraction of decades).
# If alignment drops many decades, lower this (e.g., 0.4).
ANCHOR_MIN_FRAC = 0.6

# Spectering config (time-mixing)
SPECTER_WEIGHTING = "exponential_decay"   # "exponential_decay" or "recency_bias"
SPECTER_ALPHA = 0.7                      # higher = more weight on recent decades
SPECTER_MIN_WEIGHT = 0.05                # floor on far-past contributions

# %% [markdown]
# ## 1) Loaders + alignment

# %%
def normalize_rows(W: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    W = W.astype(np.float32, copy=False)
    norms = np.linalg.norm(W, axis=1, keepdims=True)
    norms = np.maximum(norms, eps)
    return W / norms

def _find_file_for_decade(directory: Path, decade: int, exts: Tuple[str,...]) -> Optional[Path]:
    pats = [str(directory / f"*{decade}*{ext}") for ext in exts]
    hits = []
    for pat in pats:
        hits.extend([Path(p) for p in glob.glob(pat)])
    hits = sorted(hits, key=lambda p: (len(p.name), p.name))
    return hits[0] if hits else None

def list_sgns_decades(sgns_dir: Path) -> List[int]:
    if not sgns_dir.exists():
        return []
    decades = set()
    for p in sgns_dir.glob("*.npy"):
        m = re.search(r"(\d{4})", p.name)
        if m:
            y = int(m.group(1))
            if y % 10 == 0:
                decades.add(y)
    return sorted(decades)

def load_sgns_decade(decade: int, sgns_dir: Path) -> Tuple[np.ndarray, List[str], Dict[str,int]]:
    w_path = _find_file_for_decade(sgns_dir, decade, (".npy",))
    v_path = _find_file_for_decade(sgns_dir, decade, (".pkl", ".pickle"))
    if w_path is None or v_path is None:
        raise FileNotFoundError(f"Missing SGNS files for {decade} in {sgns_dir} (need .npy + vocab .pkl/.pickle)")

    W = normalize_rows(np.load(str(w_path)))
    with open(v_path, "rb") as f:
        vocab = list(pickle.load(f))

    if len(vocab) != W.shape[0]:
        raise ValueError(
            f"{decade}: vocab length {len(vocab)} != W rows {W.shape[0]} for {w_path.name}. "
            "This usually means the vocab file doesn't match the .npy file for that decade."
        )

    w2i = {w:i for i,w in enumerate(vocab)}
    return W, vocab, w2i

def build_alignment(load_fn, decades: List[int], ref_decade: int, stable_words: List[str]):
    """Align every decade to ref_decade via orthogonal Procrustes on shared anchors."""
    W_ref, vocab_ref, w2i_ref = load_fn(ref_decade)
    anchors = [w for w in stable_words if w in w2i_ref]
    if len(anchors) < 8:
        raise RuntimeError(f"Too few anchors present in reference decade {ref_decade}: {len(anchors)}")

    aligned = {}
    for d in decades:
        W, vocab, w2i = load_fn(d)
        shared = [w for w in anchors if w in w2i]
        if len(shared) < 8:
            continue

        idx_d   = np.array([w2i[w] for w in shared], dtype=int)
        idx_ref = np.array([w2i_ref[w] for w in shared], dtype=int)

        A_d   = W[idx_d]
        A_ref = W_ref[idx_ref]

        R, _ = orthogonal_procrustes(A_d, A_ref)
        W_aligned = normalize_rows(W @ R)
        aligned[d] = (W_aligned, vocab, w2i)

    return aligned

# %% [markdown]
# ## 2) Anchor selection

# %%
def is_ok_anchor(w: str) -> bool:
    if len(w) < 2 or len(w) > 60:
        return False
    if " " in w:
        return False
    return True

def build_anchors_by_ref_intersection(
    load_fn,
    decades: List[int],
    ref_decade: int,
    n_anchors: int = 5000,
    seed: int = 7,
    min_frac: float = 0.6,
) -> List[str]:
    W_ref, vocab_ref, w2i_ref = load_fn(ref_decade)
    ref_words = [w for w in vocab_ref if is_ok_anchor(w)]
    ref_set = set(ref_words)

    counts = {w: 0 for w in ref_words}
    for d in decades:
        W, vocab, w2i = load_fn(d)
        for w in ref_set:
            if w in w2i:
                counts[w] += 1

    need = max(8, int(np.ceil(min_frac * len(decades))))
    eligible = [w for w, c in counts.items() if c >= need]

    # Fallback: intersect ref with the median decade
    if len(eligible) < 50:
        mid = decades[len(decades)//2]
        W_mid, vocab_mid, w2i_mid = load_fn(mid)
        eligible = [w for w in ref_words if w in w2i_mid]

    if len(eligible) < 8:
        raise RuntimeError(
            f"Too few anchors after fallbacks: {len(eligible)}. "
            "Likely vocab mismatch across decades (wrong .pkl paired with .npy) or extremely disjoint vocabs."
        )

    rng = np.random.default_rng(seed)
    if len(eligible) > n_anchors:
        eligible = list(rng.choice(eligible, size=n_anchors, replace=False))
    return eligible

# %% [markdown]
# ## 3) Discover decades + build aligned baseline SGNS

# %%
sgns_decades = list_sgns_decades(SGNS_DIR)
if not sgns_decades:
    raise RuntimeError(f"No SGNS decades found in {SGNS_DIR}. Check filenames (.npy + vocab .pkl/.pickle).")

print("SGNS decades:", sgns_decades)

REF_DECADE = sgns_decades[-1]
print("REF_DECADE:", REF_DECADE)

# Quick diagnostic: show which files are being paired for a few decades
print("\nFile pairing check (first 6 decades):")
for d in sgns_decades[:6]:
    w_path = _find_file_for_decade(SGNS_DIR, d, (".npy",))
    v_path = _find_file_for_decade(SGNS_DIR, d, (".pkl",".pickle"))
    print(d, "|", (w_path.name if w_path else None), "|", (v_path.name if v_path else None))

anchors = build_anchors_by_ref_intersection(
    load_fn=lambda d: load_sgns_decade(d, SGNS_DIR),
    decades=sgns_decades,
    ref_decade=REF_DECADE,
    n_anchors=N_ANCHORS,
    seed=ANCHOR_SEED,
    min_frac=ANCHOR_MIN_FRAC,
)
print("\nn_anchors:", len(anchors))

sgns_aligned = build_alignment(
    load_fn=lambda d: load_sgns_decade(d, SGNS_DIR),
    decades=sgns_decades,
    ref_decade=REF_DECADE,
    stable_words=anchors,
)

SGNS_DECADES_ALIGNED = sorted(sgns_aligned.keys())
print("Aligned decades:", SGNS_DECADES_ALIGNED)
# Out:
# SGNS decades: [1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920]
# REF_DECADE: 1920
#
# File pairing check (first 6 decades):
# 1800 | 1800-w.npy | 1800-vocab.pkl
# 1810 | 1810-w.npy | 1810-vocab.pkl
# 1820 | 1820-w.npy | 1820-vocab.pkl
# 1830 | 1830-w.npy | 1830-vocab.pkl
# 1840 | 1840-w.npy | 1840-vocab.pkl
# 1850 | 1850-w.npy | 1850-vocab.pkl
#
# n_anchors: 5000
# Aligned decades: [1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920]

# %% [markdown]
# ## 4) Build spectered SGNS

# %%
def load_spectered_from_aligned(
    aligned: Dict[int, Tuple[np.ndarray, List[str], Dict[str,int]]],
    decades_ordered: List[int],
    weighting_scheme: str = "exponential_decay",
    alpha: float = 0.7,
    min_weight: float = 0.05,
) -> Dict[int, Tuple[np.ndarray, List[str], Dict[str,int]]]:
    """Create a spectered version: each decade vector is a weighted mix of current+past aligned decades."""
    decades_ordered = [d for d in decades_ordered if d in aligned]
    if not decades_ordered:
        raise RuntimeError("No decades available in aligned dict for spectering.")

    spectered = {}
    for i, cur_dec in enumerate(decades_ordered):
        W_cur, vocab_cur, w2i_cur = aligned[cur_dec]
        W_spec = np.zeros_like(W_cur)

        if weighting_scheme == "recency_bias":
            denom = (i + 1) * (i + 2) / 2.0  # 1+2+...+(i+1)

        for word in vocab_cur:
            idx_cur = w2i_cur[word]
            v_acc = np.zeros(W_cur.shape[1], dtype=np.float32)
            w_acc = 0.0

            for j in range(i + 1):
                past_dec = decades_ordered[j]
                W_p, vocab_p, w2i_p = aligned[past_dec]
                if word not in w2i_p:
                    continue

                if weighting_scheme == "exponential_decay":
                    dist = i - j
                    w = alpha ** dist
                    w = max(w, min_weight)
                elif weighting_scheme == "recency_bias":
                    w = (j + 1) / denom
                else:
                    raise ValueError("Unknown weighting_scheme")

                v_acc += w * W_p[w2i_p[word]]
                w_acc += w

            if w_acc > 0:
                W_spec[idx_cur] = v_acc / w_acc

        spectered[cur_dec] = (normalize_rows(W_spec), vocab_cur, w2i_cur)

    return spectered

sgns_spectered = load_spectered_from_aligned(
    aligned=sgns_aligned,
    decades_ordered=SGNS_DECADES_ALIGNED,
    weighting_scheme=SPECTER_WEIGHTING,
    alpha=SPECTER_ALPHA,
    min_weight=SPECTER_MIN_WEIGHT,
)

print("Built spectered SGNS for decades:", sorted(sgns_spectered.keys())[:5], "...", sorted(sgns_spectered.keys())[-5:])
# Out:
# Built spectered SGNS for decades: [1800, 1810, 1820, 1830, 1840] ... [1880, 1890, 1900, 1910, 1920]

# %% [markdown]
# ## 5) Evaluation utilities

# %%
# Display-token filter: looser than anchors, but avoids obvious junk in tables.
RE_HAS_DIGIT = re.compile(r"\d")
RE_BAD = re.compile(r"[^a-zA-Z_\-']")  # allow underscores/hyphen/apostrophe

def is_good_display_token(w: str) -> bool:
    if w is None:
        return False
    if len(w) < 2 or len(w) > 40:
        return False
    if RE_HAS_DIGIT.search(w):
        return False
    if RE_BAD.search(w):
        return False
    return True

def topk_neighbors(W: np.ndarray, vocab: List[str], w2i: Dict[str,int], term: str, k: int = 25) -> List[Tuple[str, float]]:
    if term not in w2i:
        return []
    i = w2i[term]
    v = W[i]
    sims = W @ v
    sims[i] = -np.inf
    k_eff = min(k, len(sims)-1)
    idx = np.argpartition(sims, -k_eff)[-k_eff:]
    idx = idx[np.argsort(-sims[idx])]
    return [(vocab[j], float(sims[j])) for j in idx]

def clean_neighbors(neigh: List[Tuple[str, float]], keep_k: int = 12) -> List[str]:
    out = []
    for w, _ in neigh:
        if is_good_display_token(w):
            out.append(w)
        if len(out) >= keep_k:
            break
    return out

def neighbor_trail(term: str,
                   emb: Dict[int, Tuple[np.ndarray, List[str], Dict[str,int]]],
                   k: int = 75,
                   keep_k: int = 12) -> pd.DataFrame:
    rows = []
    for d,(W,vocab,w2i) in sorted(emb.items()):
        neigh = clean_neighbors(topk_neighbors(W, vocab, w2i, term, k=k), keep_k=keep_k)
        rows.append({"decade": d, "neighbors": ", ".join(neigh)})
    return pd.DataFrame(rows)

def neighbor_overlap(term: str,
                     emb: Dict[int, Tuple[np.ndarray, List[str], Dict[str,int]]],
                     k: int = 100,
                     keep_k: int = 25) -> pd.DataFrame:
    decades = sorted(emb.keys())
    rows = []
    prev = None
    prev_dec = None
    for d in decades:
        W,vocab,w2i = emb[d]
        neigh = clean_neighbors(topk_neighbors(W, vocab, w2i, term, k=k), keep_k=keep_k)
        s = set(neigh)
        if prev is not None and len(s) > 0:
            jacc = len(prev & s) / max(len(prev | s), 1)
            rows.append({"decade": d, "prev_decade": prev_dec, "jaccard": float(jacc)})
        prev = s
        prev_dec = d
    return pd.DataFrame(rows)

def adjacent_change(term: str,
                    emb: Dict[int, Tuple[np.ndarray, List[str], Dict[str,int]]]) -> pd.DataFrame:
    decades = sorted(emb.keys())
    rows = []
    prev_vec = None
    prev_dec = None
    for d in decades:
        W,vocab,w2i = emb[d]
        if term not in w2i:
            prev_vec, prev_dec = None, None
            continue
        v = W[w2i[term]]
        if prev_vec is not None:
            rows.append({"decade": d, "prev_decade": prev_dec, "cos_to_prev": float(v @ prev_vec)})
        prev_vec, prev_dec = v, d
    return pd.DataFrame(rows)

def plot_two_series(df_a: pd.DataFrame, df_b: pd.DataFrame, x: str, y: str, label_a: str, label_b: str, title: str):
    plt.figure()
    if not df_a.empty:
        plt.plot(df_a[x], df_a[y], marker="o", label=label_a)
    if not df_b.empty:
        plt.plot(df_b[x], df_b[y], marker="o", label=label_b)
    plt.title(title)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.legend()
    plt.show()

def coverage(term: str, emb) -> int:
    return sum(1 for _,(_,_,w2i) in emb.items() if term in w2i)

# %% [markdown]
# ## 6) baseline SGNS vs spectered SGNS

# %%
# Pick terms to compare (edit freely)
TARGET_WORDS = [
    "master", "slave", "negro", "cotton",
    "man", "woman", "child", "house", "room", "work", "money", "horse",
    "gay", "broadcast", "radio", "wireless", "telegraph", "telephone",
    "awful", "nice", "silly", "engine", "factory", "labor",
]

for term in TARGET_WORDS:
    print("\n" + "="*90)
    print(f"TERM: {term} | baseline coverage={coverage(term, sgns_aligned)} | spectered coverage={coverage(term, sgns_spectered)}")

    print("\nSGNS baseline neighbors (clean)")
    display(neighbor_trail(term, sgns_aligned, k=K_NEIGHBORS, keep_k=KEEP_K))

    print("\nSGNS spectered neighbors (clean)")
    display(neighbor_trail(term, sgns_spectered, k=K_NEIGHBORS, keep_k=KEEP_K))

    # Quantitative: neighbor overlap
    df_ov_base = neighbor_overlap(term, sgns_aligned, k=K_NEIGHBORS, keep_k=25)
    df_ov_spec = neighbor_overlap(term, sgns_spectered, k=K_NEIGHBORS, keep_k=25)
    plot_two_series(df_ov_base, df_ov_spec, x="decade", y="jaccard",
                    label_a="SGNS baseline", label_b="SGNS spectered",
                    title=f"Neighbor overlap (Jaccard, top-25): {term}")

    # Drift plot
    df_drift_base = adjacent_change(term, sgns_aligned)
    df_drift_spec = adjacent_change(term, sgns_spectered)
    plot_two_series(df_drift_base, df_drift_spec, x="decade", y="cos_to_prev",
                    label_a="SGNS baseline", label_b="SGNS spectered",
                    title=f"Adjacent drift (cos to prev): {term}")
# Out:
# ==========================================================================================
# TERM: master | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                   neighbors
# 0        masters, mistress, wardens, owner, ordnance, apprentice, deputy, requests, chamberlain, provost, assistants, rolls
# 1                  masters, mistress, overseer, wardrobe, fellows, wardens, school, adjutant, deputy, warden, emanuel, mate
# 2   mistress, masters, wardens, holdenough, kerneguy, wildrake, employer, adjutant, tomkins, commands, fellows, bridgenorth
# 3        masters, mistress, owner, bates, employer, wardens, bridgenorth, worshipful, fellows, chiffinch, provost, overseer
# 4            mistress, masters, owner, mastership, worshipful, innkeeper, deputy, sutton, servant, patron, provost, ruthven
# 5       masters, mistress, seadrift, servant, owner, mastership, calatrava, worshipful, employer, chiffinch, crib, overseer
# 6               masters, mistress, mate, servant, worshipful, employer, steward, owner, assistant, mastership, balliol, art
# 7             masters, mistress, mate, worshipful, owner, servant, rugby, assistant, apprentice, servants, employer, patron
# 8   masters, mistress, taylors, charterhouse, calatrava, rugby, assistant, hospitallers, worshipful, tutor, patron, servant
# 9        mistress, masters, rugby, steward, holdenough, bally, assistant, charterhouse, kerneguy, foreman, worshipful, mate
# 10             masters, mistress, peterhouse, rugby, fettes, tomkins, servant, patron, balliol, assistant, mate, proficient
# 11            mistress, masters, servant, apprentice, worshipful, steward, builder, craft, mate, organist, disciple, doctor
# 12         mistress, masters, servant, apprentice, patron, tutor, workman, overseer, disciple, ballantrae, wardens, builder
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                    neighbors
# 0         masters, mistress, wardens, owner, ordnance, apprentice, deputy, requests, chamberlain, provost, assistants, rolls
# 1              masters, mistress, wardens, apprentice, fellows, provost, mate, school, overseer, deputy, barber, chamberlain
# 2                 masters, mistress, wardens, apprentice, fellows, senior, chaplain, emanuel, deputy, overseer, mate, school
# 3                masters, wardens, mistress, employer, steward, fellows, senior, overseer, provost, owner, keeper, assistant
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                 neighbors
# 0          edition, volume, materials, finished, works, editions, worked, poem, translation, voluminous, prefixed, quarto
# 1     works, finished, edition, materials, publication, translation, finish, volume, task, editions, supplement, treatise
# 2           works, edition, finished, translation, poem, accomplish, materials, finish, volume, labours, author, editions
# 3         works, edition, finished, finish, compilation, materials, labours, poem, translation, volume, book, publication
# 4   works, finish, finished, edition, treatise, compilation, dedicate, labours, translation, supererogation, book, volume
# 5       works, compilation, edition, finished, finish, labours, materials, book, volume, supererogation, author, treatise
# 6    works, supererogation, finish, finished, compilation, task, completion, working, accomplish, worked, materials, book
# 7    finish, works, finished, supererogation, task, working, worked, compilation, accomplish, labours, labour, completion
# 8         finish, finished, task, works, working, worked, supererogation, labours, compilation, editing, labors, dedicate
# 9             finish, working, works, finished, task, supererogation, editing, labours, done, worked, compilation, labors
# 10                 task, working, finish, works, editing, labors, labours, worked, done, completion, finished, undertaken
# 11                     task, done, working, worked, works, finish, editing, labors, undertaken, completion, job, finished
# 12                       done, worked, works, task, editing, working, job, program, labors, undertaken, labours, research
# ==========================================================================================
# TERM: money | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                   neighbors
# 0     sums, cash, lending, specie, monies, funds, sum, defray, expended, appropriation, securities, coffers
# 1       sums, sum, repayment, monies, funds, cash, purchase, specie, premium, pounds, dividends, securities
# 2                 sums, sum, moneys, payment, funds, monies, specie, pounds, deducted, amount, loan, defray
# 3               sums, sum, funds, cash, purchase, payment, specie, amount, repayment, defray, loan, surplus
# 4         sums, sum, cash, purchase, funds, moneys, disbursement, pay, payment, assignats, loan, remittance
# 5   sums, cash, disbursed, discounted, expending, moneys, sum, reimbursed, redeemable, funds, buy, purchase
# 6                           sums, cash, sum, moneys, purchase, loaned, buy, funds, loan, paid, payment, pay
# 7                               sums, cash, moneys, sum, funds, coin, buy, pay, loans, loan, currency, paid
# 8           sums, cash, moneys, reimbursement, disposable, funds, sum, pay, paid, coin, pocketed, embezzled
# 9                 sums, cash, dollars, purchase, pay, funds, sum, moneys, amount, payment, purchasing, coin
# 10                    sums, disburse, funds, sum, usurious, dollars, buy, pay, moneys, cash, expended, coin
# 11                   sums, funds, buy, expended, pay, spend, borrow, sum, dollars, spending, lender, moneys
# 12                   sums, funds, dollars, buy, sum, expended, invest, borrow, cash, loaned, repayment, pay
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                 neighbors
# 0   sums, cash, lending, specie, monies, funds, sum, defray, expended, appropriation, securities, coffers
# 1           sums, cash, monies, specie, sum, lending, funds, defray, deducted, purchase, loan, purchasing
# 2              sums, cash, sum, monies, specie, funds, moneys, deducted, defray, loan, expended, purchase
# 3               sums, cash, sum, specie, funds, monies, purchase, loan, amount, payment, moneys, expended
# 4             sums, cash, funds, sum, purchase, specie, monies, loan, moneys, amount, expended, purchases
# 5              cash, sums, funds, purchase, moneys, monies, specie, sum, loan, pay, discounted, repayment
# 6                 cash, sums, purchase, monies, funds, moneys, sum, loan, purchases, specie, pay, payment
# 7                  cash, sums, purchase, funds, moneys, purchases, loan, pay, sum, buy, monies, repayment
# 8                cash, sums, purchase, funds, moneys, pay, purchases, coin, sum, buy, purchasing, payment
# 9              cash, sums, purchase, funds, loaned, pay, purchases, moneys, purchasing, buy, coin, refund
# 10               sums, cash, loaned, funds, pay, disburse, purchases, purchase, coin, refund, buy, moneys
# 11          sums, cash, funds, loaned, pay, disburse, purchase, buy, purchases, expend, refund, repayment
# 12         sums, cash, funds, loaned, buy, disburse, purchases, expend, pay, purchase, purchasing, refund
# ==========================================================================================
# TERM: horse | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                       neighbors
# 0                rider, mule, dragoons, troop, alighted, spurs, saddle, dismounted, horsemen, ass, horses, shoe
# 1       mule, horses, gallop, saddle, cavalry, horsemen, alighted, waggon, mounted, horseman, dismounted, troop
# 2          saddled, cavalry, dragoons, horses, hoof, steed, mounted, mule, spurred, horsemen, charger, dismount
# 3               horses, troop, steed, saddle, racing, horsemen, cavalry, galloped, rode, saddled, charger, mule
# 4   horses, dismounting, saddle, steed, alighting, gig, mounted, dragoon, mules, cavalry, dismounted, harnessed
# 5        horses, cavalry, reined, bridled, steed, saddle, dismounting, dismounted, hobby, grenadier, rider, nag
# 6                          horses, pony, dog, steed, mule, dismounting, saddle, ass, cart, bridle, mare, reined
# 7                     horses, steed, pony, mule, dismounted, donkey, cavalry, rider, mules, hobby, driver, cart
# 8            horses, dismounting, mule, hitched, fleetest, pony, steed, dismounted, saddle, rider, gallop, cart
# 9            horses, remounted, steed, pony, crupper, mule, gelding, picketed, saddle, dismounted, cart, sleigh
# 10      horses, remounted, hodson, pony, picketed, saddle, gelding, mule, steed, fleetness, courser, dismounted
# 11                            horses, mule, pony, cart, bridle, rider, dog, saddle, buggy, steed, mules, donkey
# 12                            horses, mule, saddle, cart, pony, donkey, mules, rode, camel, bridle, steed, ride
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                  neighbors
# 0           rider, mule, dragoons, troop, alighted, spurs, saddle, dismounted, horsemen, ass, horses, shoe
# 1       mule, troop, saddle, horses, dragoons, rider, alighted, horsemen, gallop, dismounted, cavalry, ass
# 2     mule, horses, dragoons, saddle, troop, cavalry, horsemen, mounted, rider, alighted, cart, dismounted
# 3    horses, mule, troop, saddle, horsemen, dragoons, steed, dismounted, rider, mounted, cavalry, alighted
# 4   horses, steed, mule, saddle, mounted, troop, rider, dismounting, dismounted, dragoons, saddled, gallop
# 5      horses, steed, mule, saddle, mounted, dismounting, dismounted, rider, pony, cavalry, troop, saddled
# 6          horses, mule, pony, steed, dismounting, saddle, dismounted, mounted, team, saddled, cart, wagon
# 7          horses, pony, steed, mule, dismounting, saddle, dismounted, cart, team, mounted, rider, saddled
# 8           horses, pony, mule, steed, dismounting, team, rider, hitched, cart, donkey, dismounted, saddle
# 9         horses, pony, mule, steed, dismounting, cart, donkey, saddle, rider, dismounted, remounted, team
# 10       horses, pony, remounted, mule, steed, saddle, dismounting, dismounted, rider, cart, saddled, team
# 11           horses, pony, mule, remounted, rider, steed, donkey, saddle, cart, saddled, dismounted, buggy
# 12          horses, pony, mule, donkey, remounted, rider, steed, cart, saddle, buggy, dismounted, elephant
# ==========================================================================================
# TERM: gay | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                
# 6          machine, engines, steam, locomotive, pump, machinery, wheel, boiler, boilers, lever, wheels, machines
# 7         machine, engines, steam, locomotive, pump, machinery, boilers, boiler, piston, wheel, machines, wheels
# 8        engines, machine, steam, locomotive, pump, machinery, boilers, boiler, piston, machines, wheel, pumping
# 9       machine, engines, steam, locomotive, pump, boiler, boilers, machinery, piston, turbines, machines, wheel
# 10        engines, machine, steam, locomotive, boiler, pump, boilers, machinery, gearing, piston, turbine, pumps
# 11        engines, locomotive, steam, machine, pump, boiler, turbine, motors, turbines, gearing, piston, boilers
# 12  engines, locomotive, pump, machine, steam, turbine, boiler, motors, compressor, boilers, turbines, propeller
# ==========================================================================================
# TERM: factory | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                            neighbors
# 0                 petersburg, bruges, antwerp, commandant, hampton, birmingham, copenhagen, cruz, moscow, plymouth, montreal, panama
# 1                               factories, surat, batavia, fort, aleppo, smyrna, dutch, antwerp, canton, hamburgh, ostend, merchants
# 2             factories, manufactory, leone, leghorn, manufactories, cochin, quay, trading, martinique, arsenal, pondicherry, bengal
# 3   factories, trading, apothecaries, india, establishment, mill, manufactory, banking, manufactories, mills, investment, stationers
# 4             factories, mills, mill, shop, workshops, manufactory, workshop, trading, ostend, establishment, superintendent, lowell
# 5                factories, foundry, mill, mills, surat, working, workshop, shop, machinery, workshops, superintendent, killingworth
# 6            manufactory, factories, manufactories, mills, workshop, shop, workshops, warehouse, miners, manufacture, forges, woolen
# 7                     factories, mills, manufactory, mill, workshop, shop, workshops, foundry, surat, manufacturing, machine, cotton
# 8                      factories, mill, mills, workshops, brewery, manufacturing, shop, shops, workshop, foundry, woolen, industries
# 9                        factories, surat, foundries, mill, workshop, mills, collieries, shop, workshops, manufactories, farm, shops
# 10                     factories, shop, manufactory, workshop, mill, planing, mills, breweries, workshops, shops, potteries, workmen
# 11                            factories, workshop, workshops, shop, bakery, farm, textile, shops, mills, operatives, mill, warehouse
# 12               factories, shop, workshop, workshops, mill, shops, workers, operatives, manufacturing, textile, blacksmith, foundry
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                              neighbors
# 0                   petersburg, bruges, antwerp, commandant, hampton, birmingham, copenhagen, cruz, moscow, plymouth, montreal, panama
# 1                              antwerp, surat, canton, batavia, fort, venetian, dutch, bruges, factories, montreal, petersburg, madras
# 2                                    factories, antwerp, canton, surat, dutch, resident, lisbon, trading, bruges, fort, madras, cochin
# 3              factories, trading, ostend, manufactory, merchants, resident, calcutta, canton, birmingham, stationers, india, montreal
# 4   factories, manufactory, trading, ostend, calcutta, manufactories, canton, warehouse, birmingham, carpenters, singapore, warehouses
# 5            factories, manufactory, trading, shop, mills, superintendent, foundry, manufactories, mill, warehouse, carpenters, canton
# 6     factories, manufactory, shop, manufactories, mills, warehouse, trading, superintendent, workshops, workshop, foundry, carpenters
# 7          factories, manufactory, mills, shop, foundry, manufactories, workshop, workshops, mill, warehouse, superintendent, boarding
# 8                       factories, manufactory, mills, foundry, shop, manufactories, workshops, mill, workshop, warehouse, shops, farm
# 9                    factories, manufactory, mills, foundry, shop, workshops, manufactories, mill, workshop, brewery, surat, foundries
# 10                   factories, manufactory, workshops, workshop, shop, mills, foundry, manufactories, mill, breweries, brewery, shops
# 11                        factories, manufactory, workshop, workshops, shop, mills, foundry, manufactories, farm, shops, grocery, mill
# 12                        factories, workshop, shop, workshops, foundry, manufactory, mills, grocery, shops, mill, farm, manufacturing
# ==========================================================================================
# TERM: labor | baseline coverage=13 | spectered coverage=13
#
# SGNS baseline neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                            neighbors
# 0      labour, wages, workman, labourers, manufacturer, unproductive, husbandman, earned, labourer, manufacturing, regulates, trades
# 1                                   labour, toil, earnings, husbandman, earn, hoc, menial, wages, drudgery, working, earned, labours
# 2                labour, opus, earnings, unproductive, agricultural, products, wages, remuneration, earn, drudgery, labors, consumes
# 3              labour, toil, wages, labors, industry, remuneration, labourer, earnings, labourers, labours, laborers, productiveness
# 4                        labour, toil, industry, wages, remuneration, earnings, laborious, earn, labourers, outlay, cost, employment
# 5         labour, toil, industry, laborers, labourer, laborer, wages, productiveness, remuneration, labouring, producer, remunerated
# 6                labour, wages, laborers, toil, remuneration, products, labourers, laborer, employment, industry, service, producers
# 7                              labour, toil, wages, labours, earnings, laborer, labors, industry, remuneration, labourer, cost, work
# 8                 labour, industry, toil, wages, exploitation, workpeople, labourers, laborer, machinery, cost, employment, laborers
# 9          labour, toil, wages, industry, workingman, employment, laborers, labourers, capital, productivity, operatives, productive
# 10      labour, laborer, remunerate, employers, wages, remuneration, productivity, toil, workers, overstocked, unskilled, productive
# 11                labour, wages, unskilled, federation, unions, earners, productivity, bargaining, employers, cost, trades, laborers
# 12  labour, unskilled, productivity, wages, workers, bargaining, federation, specialization, unions, earners, turnover, remuneration
# SGNS spectered neighbors (clean)
#     decade  \
# 0     1800
# 1     1810
# 2     1820
# 3     1830
# 4     1840
# 5     1850
# 6     1860
# 7     1870
# 8     1880
# 9     1890
# 10    1900
# 11    1910
# 12    1920
#
#                                                                                                                          neighbors
# 0    labour, wages, workman, labourers, manufacturer, unproductive, husbandman, earned, labourer, manufacturing, regulates, trades
# 1            labour, husbandman, wages, toil, earned, earnings, earn, unproductive, manufacturer, labourers, industry, cultivators
# 2                   labour, wages, earnings, husbandman, unproductive, toil, earn, labourer, earned, labourers, products, industry
# 3                   labour, toil, earnings, wages, labourer, unproductive, industry, labourers, earn, husbandman, products, labors
# 4           labour, toil, wages, earnings, remuneration, industry, labourers, earn, labourer, unproductive, employment, husbandman
# 5         labour, toil, earnings, wages, remuneration, industry, laborer, labourer, labourers, laborers, productiveness, labouring
# 6              labour, toil, remuneration, wages, earnings, laborer, industry, laborers, labourer, labourers, producer, employment
# 7               labour, toil, wages, remuneration, earnings, industry, laborer, labourer, producers, laborers, labourers, producer
# 8                   labour, toil, wages, industry, laborer, earnings, remuneration, producers, labourers, labourer, laborers, cost
# 9             labour, toil, wages, industry, laborer, laborers, labourer, labourers, producers, earnings, employment, remuneration
# 10            labour, wages, toil, laborer, industry, producers, labourer, remuneration, laborers, employment, labourers, earnings
# 11  labour, wages, unskilled, productivity, toil, laborer, transportation, laborers, producers, employment, remuneration, industry
# 12            labour, wages, productivity, unskilled, laborer, earners, wage, toil, remuneration, bargaining, employment, laborers
